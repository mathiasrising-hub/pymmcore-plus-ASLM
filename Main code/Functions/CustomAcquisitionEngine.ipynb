# %%
from pymmcore_plus import CMMCorePlus
from pymmcore_plus.mda import MDAEngine
import useq
import stages_movement
import numpy as np
bound = [[-40, -20], [7, 14], [0, 4]]
class No_Stage(MDAEngine):
    
    def setup_event(self, event: useq.MDAEvent) -> None:
        """Prepare state of system (hardware, etc.) for `event`."""
        # do some custom pre-setup
        super().setup_event(event)  
        # do some custom post-setup

    def exec_event(self, event: useq.MDAEvent) -> object:
        """Prepare state of system (hardware, etc.) for `event`."""
        # do some custom pre-execution
        result = super().exec_event(event)  
        # do some custom post-execution
        return result 


class Z_Stack(MDAEngine): 
    def setup_event(self, event: useq.MDAEvent) -> None:
        """Prepare state of system (hardware, etc.) for `event`."""
        # do some custom pre-setup
        self.z_move(event.metadata)
        super().setup_event(event)  
        # do some custom post-setup

    def z_move(self, metadata: dict) -> none:
        step_size = float(metadata['step_size'])
        stages_movement.jog(2, step_size, controller, bound)
        
    def exec_event(self, event: useq.MDAEvent) -> object:
        """Prepare state of system (hardware, etc.) for `event`."""
        # do some custom pre-execution
        result = super().exec_event(event)  
        # do some custom post-execution
        return result 

'''
class Tiling(MDAEngine): 
    def setup_event(self, event: useq.MDAEvent) -> None:
        """Prepare state of system (hardware, etc.) for `event`."""
        # do some custom pre-setup
        super().setup_event(event)  
        # do some custom post-setup

    def exec_event(self, event: useq.MDAEvent) -> object:
        """Prepare state of system (hardware, etc.) for `event`."""
        # do some custom pre-execution
        result = super().exec_event(event)  
        # do some custom post-execution
        return result

class Multi_Color_Z_Stack(MDAEngine): 
    def setup_event(self, event: useq.MDAEvent) -> None:
        """Prepare state of system (hardware, etc.) for `event`."""
        # do some custom pre-setup
        super().setup_event(event)  
        # do some custom post-setup

    def exec_event(self, event: useq.MDAEvent) -> object:
        """Prepare state of system (hardware, etc.) for `event`."""
        # do some custom pre-execution
        result = super().exec_event(event)  
        # do some custom post-execution
        return result

class Multi_Color_Tiling(MDAEngine): 
    def setup_event(self, event: useq.MDAEvent) -> None:
        """Prepare state of system (hardware, etc.) for `event`."""
        # do some custom pre-setup
        super().setup_event(event)  
        # do some custom post-setup

    def exec_event(self, event: useq.MDAEvent) -> object:
        """Prepare state of system (hardware, etc.) for `event`."""
        # do some custom pre-execution
        result = super().exec_event(event)  
        # do some custom post-execution
        return result
        '''
# Out:
# '\nclass Tiling(MDAEngine): \n    def setup_event(self, event: useq.MDAEvent) -> None:\n        """Prepare state of system (hardware, etc.) for `event`."""\n        # do some custom pre-setup\n        super().setup_event(event)  \n        # do some custom post-setup\n\n    def exec_event(self, event: useq.MDAEvent) -> object:\n        """Prepare state of system (hardware, etc.) for `event`."""\n        # do some custom pre-execution\n        result = super().exec_event(event)  \n        # do some custom post-execution\n        return result\n\nclass Multi_Color_Z_Stack(MDAEngine): \n    def setup_event(self, event: useq.MDAEvent) -> None:\n        """Prepare state of system (hardware, etc.) for `event`."""\n        # do some custom pre-setup\n        super().setup_event(event)  \n        # do some custom post-setup\n\n    def exec_event(self, event: useq.MDAEvent) -> object:\n        """Prepare state of system (hardware, etc.) for `event`."""\n        # do some custom pre-execution\n        result = super().exec_event(event)  \n        # do some custom post-execution\n        return result\n\nclass Multi_Color_Tiling(MDAEngine): \n    def setup_event(self, event: useq.MDAEvent) -> None:\n        """Prepare state of system (hardware, etc.) for `event`."""\n        # do some custom pre-setup\n        super().setup_event(event)  \n        # do some custom post-setup\n\n    def exec_event(self, event: useq.MDAEvent) -> object:\n        """Prepare state of system (hardware, etc.) for `event`."""\n        # do some custom pre-execution\n        result = super().exec_event(event)  \n        # do some custom post-execution\n        return result\n        '

# %%
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[2], line 4
#       2 mmc.enableDebugLog(True)
#       3 # Load the correct configuration file. NB! If a new configuration file is created, change the path to the new configuration file
# ----> 4 mmc.loadSystemConfiguration(r"\Users\Hannah\Desktop\configuration\Configuration_new.cfg")
#
# File ~\anaconda3\envs\microscope\Lib\site-packages\pymmcore_plus\core\_mmcore_plus.py:467, in CMMCorePlus.loadSystemConfiguration(self, fileName)
#     465     raise FileNotFoundError(f"Path does not exist: {fpath}")
#     466 self._last_sys_config = str(fpath.resolve())
# --> 467 super().loadSystemConfiguration(self._last_sys_config)
#
# OSError: Line 38: Property,Core,Initialize,1
# Error in device "NIDAQAO-Dev1/ao0": The specified resource is reserved. The operation could not be completed as specified. (21000)
